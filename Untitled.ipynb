# %%
Day Objectives
Regular Expression Constructing Regular Expression for various use cases Regular Expressions Module and related in python improving the Contacts application with name and phone number validation File Handling Text Files Upgrading the Contacts Application to store

Regular Expression
pattern matching
Symbolic Notation of a pattern
Pattern : Format Which Repeats
Pattern(RE) - The set of all strings match that pattern
[0-9] -> Any digit

[a-z] -> Any lower case alphabet

[2468] -> All single digit muples of 2

^[0-9]{1} ->only one single digit numbers

^[0-9]{1} ->only 3 digit numbers

[0-9]*0$ -> All multiples of 10

^[0-9][0-9]*[05] ([5])  -> all multiples of 5 other than 5

[1-9][0-9]{9}$ -> All 10 digits numbers

(word) or [w][o][r][d] ->searching a word

-^[6-9][0-9]{9} 𝑜𝑟[0][6−9][0−9] {9}^[+][9][1] -> validating a indian phone number

-^[0-9] -Email validation(username@domain.extention

-Username
    -Length if username : [6,15]
    -No special characters other than _ .
    -should begin and end with _ and .
    - Characters set : all digits and lower case alphabet

-domain
     -Length of domain : [3,18]
     - no special characters
     - characters set : all digits and lower case alphabet
-extension 
      -Lentgth of extension : [2,4]
      -no special characters
      -character set : alphabets lower case
-Any string of length of 5 that starts with a and ends eith z

^[a]...[z]$ -^[a].*[z] -> any stering any length starts with a and end with z

#function to validate a phone number
​
import re
def phonenumbervalidator(num):
    pattern = '^[6-9][0-9]{9}'
    if re.match(pattern,str(num)):
        print("valid number")
    else:
        print("Invalid")
    return
phonenumbervalidator(9177086399)
​
​
def emailvalidator(email):
    pattern= '^[0-9a-z][0-9a-z_.]{4,13}[0-9a-z][@][0-9a-z]{3,18}[.][2-4][a-z]{2,4}$'
    if re.match(pattern,email):
        return True
    return False
emailvalidator("sravanthi@gmail.com")
​
valid number
False
contacts = {"name1":[9177086377,"name1@domain.ext"],"name2":[7382645349,"name2@domain.ext"]}
def addcontact(name,phone,email):
    if name in contacts:
        print(name,"already exists")
    else:
        if phonenumbervalidator(phone):
            print("invalid phone number")
            return
        if not emailvalidator(email):
            print("invalid email adress")
            return
        newcontact = []
        newcontact.append(phone)
        newcontact.append(email)
        contacts[name] = newcontact
    return
addcontact("name3",917708639,"abcde@gmail.com")
        
​
Invalid
invalid email adress
def searchcontacts(name):
    if name in contacts:
        print(name)
        print("phone :",contacts[name][0])
        print("email :",contacts[name][1])
    else:
        print("%s does not exist" % name)
    return
searchcontacts(name)
---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-9-373b55ea8419> in <module>
      7         print("%s does not exist" % name)
      8     return
----> 9 searchcontacts(name)

NameError: name 'name' is not defined

def importcontacts(newcontacts):
    contacts.update(newcontacts)
    print(len(newcontacts.keys()),)
    return
    contacts={"name4":}
importcontacts(newcontacts)
contacts.items()
​
---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
<ipython-input-7-9a82a1ca9177> in <module>
      3     print(len(newcontacts.keys()),)
      4     return
----> 5 importcontacts(newcontacts)

NameError: name 'newcontacts' is not defined

​
#function to list all contacts
def listallcontacts():
    for contact,info in contacts.items:
        print(contact,:"\n","phone:",info[0],"\n")
    return
listallcontacts()
  File "<ipython-input-8-dceef210cb84>", line 4
    print(contact,:"\n","phone:",info[0],"\n")
                  ^
SyntaxError: invalid syntax


#function to edit contact info
def editcontact(name,phone,email):
    
​
​
​
​
​
​
​
​
​
​
  File "<ipython-input-10-ba5a21399842>", line 12
    
    ^
SyntaxError: unexpected EOF while parsing


File handling in python
File-Document containing information residing on the permanent storage

Types -text,pdf,csv

File I/O-channelling I/O data to files

Default I/O channels - Keyboard /Screen

Change I/O channel to files for Reading and Writing into files

Read a file - Input

Write to a file - output to a file

Read/write a file -open(filename,mode)

#function to read a file
def readFile(filename):
    f = open(filename,'r')
    filedata = f.read()
    f.close()
    return filedata
filename = "Datafiles/data.txt"
readFile(filename)
---------------------------------------------------------------------------
FileNotFoundError                         Traceback (most recent call last)
<ipython-input-29-f1d5c5003019> in <module>
      6     return filedata
      7 filename = "Datafiles/data.txt"
----> 8 readFile(filename)

<ipython-input-29-f1d5c5003019> in readFile(filename)
      1 #function to read a file
      2 def readFile(filename):
----> 3     f = open(filename,'r')
      4     filedata = f.read()
      5     f.close()

FileNotFoundError: [Errno 2] No such file or directory: 'Datafiles/data.txt'

def writeIntoFile(filename,filedata):
    with open(filename,'w') as f:
        f.write(filedata)
    return
filename = 'DataFiles/data.txt'
​
writeIntoFile(filename,"new data")
---------------------------------------------------------------------------
FileNotFoundError                         Traceback (most recent call last)
<ipython-input-28-aec34d3a3ffa> in <module>
      5 filename = 'DataFiles/data.txt'
      6 
----> 7 writeIntoFile(filename,"new data")

<ipython-input-28-aec34d3a3ffa> in writeIntoFile(filename, filedata)
      1 def writeIntoFile(filename,filedata):
----> 2     with open(filename,'w') as f:
      3         f.write(filedata)
      4     return
      5 filename = 'DataFiles/data.txt'

FileNotFoundError: [Errno 2] No such file or directory: 'DataFiles/data.txt'
# Out:
#   File "<ipython-input-1-4b614b7437d7>", line 1
#     Day Objectives
#                  ^
# SyntaxError: invalid syntax

# %%
#function to read a file
def readFile(filename):
    f = open(filename,'r')
    filedata = f.read()
    f.close()
    return filedata
filename = "Datafiles/data.txt"
readFile(filename)
# Out:
# 'Line1\nLine2\nLine3\n'

# %%
def writeIntoFile(filename,filedata):
    with open(filename,'w') as f:
        f.write(filedata)
    return
filename = 'Datafiles/data.txt'

writeIntoFile(filename,"new data")
